# %%
# Importing Libraries
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt 

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %% [markdown]
# Problem Statement:
# Create a box plot to visualize the distribution of salary_hour_avg for Data Scientist job postings in the United States. Label the x-axis as 'Data Scientist' and the y-axis as 'Hourly Salary ($USD)'.
#
# Hint:
# Use the DataFrames plot() method to create the box plot. Customize the x-axis and y-axis labels using plt.xlabel() and plt.ylabel().

# %%
df_US_DS = df[(df['job_title_short'] == 'Data Scientist') & (df['job_country'] == 'United States')].copy() # mora svaki uslov posebno u zagradama () ako ih ima dva ili vise
df_US_DS
# Out:
#        job_title_short                                          job_title  \
# 9       Data Scientist                                  Data Scientist II
# 17      Data Scientist                             Data Science Team Lead
# 32      Data Scientist   Sr. Data Scientist (NLP) - Full-time / Part-time
# 40      Data Scientist        Data Scientist, Data Strategy and Analytics
# 41      Data Scientist                                   Data Scientist I
# ...                ...                                                ...
# 785578  Data Scientist          Data Scientist, Advanced Motor Technology
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785651  Data Scientist             Data Scientist (Supply Chain Security)
# 785673  Data Scientist                    Asset Management Data Scientist
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#              job_location                                            job_via  \
# 9                Anywhere                                   via ZipRecruiter
# 17             Laurel, MD  via APL Careers - Johns Hopkins University App...
# 32             Dallas, TX                                       via Snagajob
# 40            Alameda, CA                                    via Trabajo.org
# 41              Paris, KY                                   via Jobs By Care
# ...                   ...                                                ...
# 785578         Newark, CA                                    via Trabajo.org
# 785648  Pleasant Hill, CA                                    via Ai-Jobs.net
# 785651   Fort Belvoir, VA                                       via LinkedIn
# 785673       New York, NY                                    via Trabajo.org
# 785692         Dayton, OH                                    via Ai-Jobs.net
#
#        job_schedule_type  job_work_from_home            search_location  \
# 9              Full-time                True    New York, United States
# 17             Full-time               False                    Georgia
# 32             Full-time               False       Texas, United States
# 40             Full-time               False  California, United States
# 41             Full-time               False                    Georgia
# ...                  ...                 ...                        ...
# 785578         Full-time               False  California, United States
# 785648         Full-time               False  California, United States
# 785651         Full-time               False                    Georgia
# 785673         Full-time               False    New York, United States
# 785692         Full-time               False    Illinois, United States
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 9      2023-04-23 13:02:57                  False                 False
# 17     2023-06-13 13:25:17                  False                  True
# 32     2023-03-13 13:07:03                  False                  True
# 40     2023-04-26 13:05:10                  False                 False
# 41     2023-11-13 14:59:39                  False                 False
# ...                    ...                    ...                   ...
# 785578 2023-05-30 06:02:25                  False                  True
# 785648 2023-04-12 06:02:51                  False                  True
# 785651 2023-01-07 07:10:51                  False                 False
# 785673 2023-10-16 06:01:53                   True                 False
# 785692 2023-04-21 06:02:31                  False                  True
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 9       United States        None              NaN              NaN
# 17      United States        None              NaN              NaN
# 32      United States        None              NaN              NaN
# 40      United States        None              NaN              NaN
# 41      United States        None              NaN              NaN
# ...               ...         ...              ...              ...
# 785578  United States        None              NaN              NaN
# 785648  United States        year         221875.0              NaN
# 785651  United States        None              NaN              NaN
# 785673  United States        None              NaN              NaN
# 785692  United States        year         157500.0              NaN
#
#                                     company_name  \
# 9                     Radwell International, LLC
# 17      Johns Hopkins Applied Physics Laboratory
# 32                                      MCKESSON
# 40                                        Abbott
# 41               Appalachian Regional Healthcare
# ...                                          ...
# 785578                              Lucid Motors
# 785648                                    84.51°
# 785651                  Defense Logistics Agency
# 785673                      JPMorgan Chase & Co.
# 785692                                    Tenet3
#
#                                                job_skills  \
# 9       [sql, python, r, mongodb, mongodb, sql server,...
# 17                                       [go, apl, excel]
# 32      [python, azure, databricks, pyspark, pandas, h...
# 40                                                   None
# 41      [r, sql, python, scala, java, c++, hadoop, tab...
# ...                                                   ...
# 785578  [go, python, sql, matlab, numpy, pandas, sciki...
# 785648                  [python, azure, snowflake, spark]
# 785651                                               [go]
# 785673                                               None
# 785692                                [python, matlab, r]
#
#                                           job_type_skills
# 9       {'analyst_tools': ['excel'], 'cloud': ['azure'...
# 17      {'analyst_tools': ['excel'], 'programming': ['...
# 32      {'cloud': ['azure', 'databricks'], 'libraries'...
# 40                                                   None
# 41      {'analyst_tools': ['tableau'], 'libraries': ['...
# ...                                                   ...
# 785578  {'libraries': ['numpy', 'pandas', 'scikit-lear...
# 785648  {'cloud': ['azure', 'snowflake'], 'libraries':...
# 785651                            {'programming': ['go']}
# 785673                                               None
# 785692         {'programming': ['python', 'matlab', 'r']}
#
# [58830 rows x 17 columns]

# %%
df_US_DS = df_US_DS.dropna(subset='salary_hour_avg')
df_US_DS
# Out:
#        job_title_short                                          job_title  \
# 734     Data Scientist  Data Scientist - NLP, regex, OpenCV, Python, A...
# 881     Data Scientist  Data Scientist with expertise in deep learning...
# 1100    Data Scientist                         Data Scientist - R, Python
# 1426    Data Scientist                                     Data Scientist
# 1551    Data Scientist                 Data Scientist for Retail Industry
# ...                ...                                                ...
# 783119  Data Scientist                                     Data Scientist
# 783522  Data Scientist                                     Data Scientist
# 783753  Data Scientist           Data Scientist 3 - Full-time / Part-time
# 785476  Data Scientist                               Data Scientist, Lead
# 785492  Data Scientist                                     Data Scientist
#
#            job_location       job_via        job_schedule_type  \
# 734            Anywhere    via Upwork               Contractor
# 881            Anywhere    via Upwork               Contractor
# 1100    Tallahassee, FL      via Dice               Contractor
# 1426           Anywhere  via LinkedIn               Contractor
# 1551           Anywhere    via Upwork               Contractor
# ...                 ...           ...                      ...
# 783119     Columbus, OH  via LinkedIn               Contractor
# 783522  Los Angeles, CA  via LinkedIn               Contractor
# 783753      Augusta, GA  via Snagajob  Full-time and Part-time
# 785476   Washington, DC  via Snagajob  Full-time and Part-time
# 785492    Arlington, VA  via Snagajob  Full-time and Part-time
#
#         job_work_from_home            search_location     job_posted_date  \
# 734                   True    Illinois, United States 2023-04-23 13:04:21
# 881                   True       Texas, United States 2023-07-02 13:05:15
# 1100                 False                    Georgia 2023-11-21 14:40:41
# 1426                  True    Illinois, United States 2023-08-16 13:05:10
# 1551                  True    Illinois, United States 2023-07-26 13:05:13
# ...                    ...                        ...                 ...
# 783119               False    Illinois, United States 2023-01-30 06:05:54
# 783522               False  California, United States 2023-01-19 06:05:26
# 783753               False                    Georgia 2023-10-13 07:18:54
# 785476               False                    Georgia 2023-11-01 06:58:10
# 785492               False                    Georgia 2023-11-01 06:58:02
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 734                     False                 False  United States
# 881                     False                 False  United States
# 1100                    False                 False  United States
# 1426                    False                 False  United States
# 1551                    False                 False  United States
# ...                       ...                   ...            ...
# 783119                  False                 False  United States
# 783522                  False                 False  United States
# 783753                  False                 False  United States
# 785476                  False                  True  United States
# 785492                  False                  True  United States
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 734           hour              NaN        15.000000
# 881           hour              NaN        35.500000
# 1100          hour              NaN        67.500000
# 1426          hour              NaN        75.000000
# 1551          hour              NaN        55.000000
# ...            ...              ...              ...
# 783119        hour              NaN        60.000000
# 783522        hour              NaN        85.000000
# 783753        hour              NaN        31.974998
# 785476        hour              NaN        47.620003
# 785492        hour              NaN        47.620003
#
#                       company_name  \
# 734                         Upwork
# 881                         Upwork
# 1100                  ArnAmy, Inc.
# 1426                Insight Global
# 1551                        Upwork
# ...                            ...
# 783119                 Robert Half
# 783522                iSpace, Inc.
# 783753  iNovex Information Systems
# 785476         Booz Allen Hamilton
# 785492         Booz Allen Hamilton
#
#                                                job_skills  \
# 734                                         [python, aws]
# 881                                                  None
# 1100       [python, r, sql, azure, pandas, hadoop, spark]
# 1426    [sql, python, sql server, oracle, aws, powerpo...
# 1551    [python, r, aws, azure, tensorflow, pytorch, k...
# ...                                                   ...
# 783119                        [r, python, go, aws, spark]
# 783522                                      [python, aws]
# 783753                     [c, shell, bash, python, perl]
# 785476                           [databricks, azure, aws]
# 785492                               [python, r, pyspark]
#
#                                           job_type_skills
# 734         {'cloud': ['aws'], 'programming': ['python']}
# 881                                                  None
# 1100    {'cloud': ['azure'], 'libraries': ['pandas', '...
# 1426    {'analyst_tools': ['powerpoint', 'outlook', 'p...
# 1551    {'cloud': ['aws', 'azure'], 'libraries': ['ten...
# ...                                                   ...
# 783119  {'cloud': ['aws'], 'libraries': ['spark'], 'pr...
# 783522      {'cloud': ['aws'], 'programming': ['python']}
# 783753  {'programming': ['c', 'shell', 'bash', 'python...
# 785476          {'cloud': ['databricks', 'azure', 'aws']}
# 785492  {'libraries': ['pyspark'], 'programming': ['py...
#
# [2100 rows x 17 columns]

# %%
plt.boxplot(df_US_DS['salary_hour_avg'])
plt.title('Hourly Distribution for Data Scientist in the US')
plt.xlabel('Data Scientist')
plt.ylabel('Hourly Salary ($USD)')
plt.show()

# %% [markdown]
# Problem Statement:
# Create a box plot to compare the distribution of salary_hour_avg for Data Analyst job postings in the United States and Canada.
#
# - Filter a DataFrame to include only 'Data Analyst' roles in these two countries.
# - Use list comprehension to create a list of DataFrames for each country.
# - Use the plt.boxplot() function to plot this list and specify the labels as countries.
# - Set the y-axis limit to 150 and the y-axis as 'Hourly Salary ($USD)'.
#
# Hint:
# Use the plt.boxplot() function to create the box plot and customize the y-axis labels using  plt.ylabel().

# %%
countries = ['United States', 'Canada']

# %%
df_US_CAN = df[(df['job_title_short'] == 'Data Analyst') & (df['job_country'].isin(countries))].copy().dropna(subset='salary_hour_avg')
df_US_CAN
# Out:
#        job_title_short                                          job_title  \
# 294       Data Analyst                              Business/Data Analyst
# 340       Data Analyst  23-00059 BI Data Analysts + Media experience -...
# 513       Data Analyst                                       Data Analyst
# 840       Data Analyst             Data Analysis/ Project Coordinator/ BA
# 954       Data Analyst                             Financial Data Analyst
# ...                ...                                                ...
# 781805    Data Analyst                    Lead Data Analytic Analyst, FIN
# 781853    Data Analyst  Remote Jr Java programmer/Data Analyst/Data Sc...
# 783013    Data Analyst                              Research Data Analyst
# 783578    Data Analyst       Lead Data Analytic Analyst, FIN - Now Hiring
# 783704    Data Analyst                                  Test Data Analyst
#
#                 job_location          job_via        job_schedule_type  \
# 294             Hartford, CT         via Dice               Contractor
# 340               California     via LinkedIn               Contractor
# 513     Long Island City, NY       via Indeed                Full-time
# 840          Jersey City, NJ         via Dice               Contractor
# 954          San Antonio, TX  via Robert Half               Contractor
# ...                      ...              ...                      ...
# 781805        Centertown, MO     via Snagajob                Full-time
# 781853      Indianapolis, IN     via Snagajob  Full-time and Part-time
# 783013     Warner Robins, GA     via Snagajob  Full-time and Part-time
# 783578             Loami, IL     via Snagajob                Full-time
# 783704         Niceville, FL     via Snagajob  Full-time and Part-time
#
#         job_work_from_home            search_location     job_posted_date  \
# 294                  False    New York, United States 2023-07-03 13:00:08
# 340                  False  California, United States 2023-02-28 13:01:46
# 513                  False    New York, United States 2023-05-09 12:59:58
# 840                  False    New York, United States 2023-09-19 12:59:57
# 954                  False       Texas, United States 2023-06-27 13:01:51
# ...                    ...                        ...                 ...
# 781805               False    Illinois, United States 2023-08-07 06:01:15
# 781853               False                    Georgia 2023-09-16 06:55:42
# 783013               False                    Georgia 2023-09-13 07:05:20
# 783578               False    Illinois, United States 2023-08-07 06:01:10
# 783704               False                    Georgia 2023-10-25 07:10:11
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 294                     False                 False  United States
# 340                      True                 False  United States
# 513                     False                 False  United States
# 840                     False                 False  United States
# 954                     False                 False  United States
# ...                       ...                   ...            ...
# 781805                  False                  True  United States
# 781853                  False                 False  United States
# 783013                  False                  True  United States
# 783578                  False                  True  United States
# 783704                  False                  True  United States
#
#        salary_rate  salary_year_avg  salary_hour_avg            company_name  \
# 294           hour              NaN        52.500000  Vector Consulting, Inc
# 340           hour              NaN        67.500000            iSpace, Inc.
# 513           hour              NaN        22.500000                  JK.com
# 840           hour              NaN        65.000000                 Ionidea
# 954           hour              NaN        76.875000             Robert Half
# ...            ...              ...              ...                     ...
# 781805        hour              NaN        23.264999            EDWARD JONES
# 781853        hour              NaN        30.660000           SynergisticIT
# 783013        hour              NaN        22.695000                HX5, LLC
# 783578        hour              NaN        23.760000            EDWARD JONES
# 783704        hour              NaN        19.580000                HX5, LLC
#
#                                                job_skills  \
# 294                                                  None
# 340      [go, sql, aws, snowflake, tableau, looker, word]
# 513                       [sql, excel, tableau, power bi]
# 840                                   [excel, powerpoint]
# 954                            [python, c, sql, sas, sas]
# ...                                                   ...
# 781805                                               None
# 781853  [java, javascript, c++, sas, sas, python, orac...
# 783013                                               None
# 783578                                               None
# 783704  [r, sql, python, java, matlab, mysql, hadoop, ...
#
#                                           job_type_skills
# 294                                                  None
# 340     {'analyst_tools': ['tableau', 'looker', 'word'...
# 513     {'analyst_tools': ['excel', 'tableau', 'power ...
# 840            {'analyst_tools': ['excel', 'powerpoint']}
# 954     {'analyst_tools': ['sas'], 'programming': ['py...
# ...                                                   ...
# 781805                                               None
# 781853  {'analyst_tools': ['sas', 'tableau'], 'cloud':...
# 783013                                               None
# 783578                                               None
# 783704  {'analyst_tools': ['excel', 'tableau', 'power ...
#
# [3996 rows x 17 columns]

# %%
job_countries = [df_US_CAN[df_US_CAN['job_country'] == country]['salary_hour_avg'] for country in countries]
job_countries
# Out:
# [294       52.500000
#  340       67.500000
#  513       22.500000
#  840       65.000000
#  954       76.875000
#              ...
#  781805    23.264999
#  781853    30.660000
#  783013    22.695000
#  783578    23.760000
#  783704    19.580000
#  Name: salary_hour_avg, Length: 3980, dtype: float64,
#  70830     25.0
#  70869     26.0
#  73362     25.0
#  303133    20.0
#  306155    70.0
#  320046    37.5
#  334412    25.0
#  422746    35.0
#  451270    34.0
#  503994    35.0
#  544317    33.0
#  574996    23.0
#  658194    22.0
#  670356    22.0
#  672618    22.0
#  684418    64.0
#  Name: salary_hour_avg, dtype: float64]

# %%
plt.boxplot(job_countries, labels=countries)
plt.ylim(0,150)
plt.ylabel('Hourly Salary ($USD)')
plt.title('Comparison of Hourly Salaries for Data Analysts in the US and Canada')
plt.show()
# Out:
# C:\Users\Korisnik\AppData\Local\Temp\ipykernel_21184\2542946922.py:1: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(job_countries, labels=countries)

# %% [markdown]
# Problem Statement:
# Create a box plot to compare the distribution of salary_hour_avg for Data Analyst, Data Engineer, and Data Scientist job postings in Canada.
# Label the x-axis as 'Job Title' and format the y-axis to have '$' before the number then label it as 'Hourly Salary (USD)'.
#
# Hint:
# Create a box plot using ax.boxplot() after setting up your figure and axes with plt.subplots().
# Customize the x-axis and y-axis labels using ax.set_xlabel() and ax.set_ylabel().
# Apply a custom formatter to the y-axis to format salary values as currency.

# %%
job_titles = ['Data Analyst', 'Data Engineer', 'Data Scientist']

# %%
df_data_jobs = df[df['job_country'] == 'Canada'].dropna(subset='salary_hour_avg')
df_data_jobs_salary = [df_data_jobs[df_data_jobs['job_title_short'] == job]['salary_hour_avg'] for job in job_titles]
df_data_jobs_salary
# Out:
# [70830     25.0
#  70869     26.0
#  73362     25.0
#  303133    20.0
#  306155    70.0
#  320046    37.5
#  334412    25.0
#  422746    35.0
#  451270    34.0
#  503994    35.0
#  544317    33.0
#  574996    23.0
#  658194    22.0
#  670356    22.0
#  672618    22.0
#  684418    64.0
#  Name: salary_hour_avg, dtype: float64,
#  164220    57.500
#  164474    75.000
#  180190    55.000
#  212339    35.000
#  277959    55.000
#  281876    76.000
#  397600    97.000
#  397617    45.000
#  401449    40.000
#  426994    26.000
#  443624    57.500
#  446129    55.000
#  479018    57.500
#  543093    50.000
#  565581    56.465
#  672345    55.000
#  699753    55.000
#  736268    62.500
#  Name: salary_hour_avg, dtype: float64,
#  26310     57.5
#  86859     25.0
#  417421    26.0
#  523581    21.0
#  Name: salary_hour_avg, dtype: float64]

# %%
df_data_jobs_salary[0]
# Out:
# 70830     25.0
# 70869     26.0
# 73362     25.0
# 303133    20.0
# 306155    70.0
# 320046    37.5
# 334412    25.0
# 422746    35.0
# 451270    34.0
# 503994    35.0
# 544317    33.0
# 574996    23.0
# 658194    22.0
# 670356    22.0
# 672618    22.0
# 684418    64.0
# Name: salary_hour_avg, dtype: float64

# %%
df_data_jobs_salary[1]
# Out:
# 164220    57.500
# 164474    75.000
# 180190    55.000
# 212339    35.000
# 277959    55.000
# 281876    76.000
# 397600    97.000
# 397617    45.000
# 401449    40.000
# 426994    26.000
# 443624    57.500
# 446129    55.000
# 479018    57.500
# 543093    50.000
# 565581    56.465
# 672345    55.000
# 699753    55.000
# 736268    62.500
# Name: salary_hour_avg, dtype: float64

# %%
df_data_jobs_salary[2]
# Out:
# 26310     57.5
# 86859     25.0
# 417421    26.0
# 523581    21.0
# Name: salary_hour_avg, dtype: float64

# %%
fig, ax = plt.subplots(1, 1)
ax.boxplot(df_data_jobs_salary, labels=job_titles)
ax.set_xlabel('Job Title')
ax.set_ylabel('Hourly Salary ($USD)')
ax.set_title('Comparison of Hourly Salaries for Data Roles in Canada')
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, pos: f'${int(y)}'))
plt.show()
# Out:
# C:\Users\Korisnik\AppData\Local\Temp\ipykernel_21184\1285922430.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(df_data_jobs_salary, labels=job_titles)
