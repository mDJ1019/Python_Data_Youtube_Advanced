# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Datadataset 
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %% [markdown]
# Problem Statement:
# Create a pivot table to count the number of job postings for each job_title_short and job_country. Display the first 10 rows of the resulting pivot table.
#
# Hint:
# Use the pivot_table() function using the parameters index and aggfunc.

# %%
df.pivot_table(index='job_title_short', aggfunc='count')
# Out:
#                            company_name  job_country  job_health_insurance  \
# job_title_short
# Business Analyst                  49063        49057                 49063
# Cloud Engineer                    12331        12329                 12331
# Data Analyst                     196070       196067                196075
# Data Engineer                    186236       186237                186241
# Data Scientist                   172281       172281                172286
# Machine Learning Engineer         14080        14078                 14080
# Senior Data Analyst               29216        29214                 29216
# Senior Data Engineer              44563        44561                 44563
# Senior Data Scientist             36957        36956                 36957
# Software Engineer                 44926        44912                 44929
#
#                            job_location  job_no_degree_mention  \
# job_title_short
# ...

# %%
df.pivot_table(index=['job_title_short', 'job_country'], aggfunc='size').head(10)
# Out:
# job_title_short   job_country
# Business Analyst  Afghanistan      4
#                   Albania         11
#                   Algeria         21
#                   Angola           1
#                   Argentina      453
#                   Armenia         29
#                   Australia      928
#                   Austria        738
#                   Azerbaijan      16
#                   Bahamas          5
# dtype: int64

# %% [markdown]
# Create a pivot table to find the maximum, minimum, and average salary_year_avg for each company_name. Display the first 5 rows of the resulting pivot table.
#
# Hint:
# Use the pivot_table() function with using the parameters values, index, and aggfunc.

# %%
pivot2 = df.pivot_table(values='salary_year_avg', index='company_name', aggfunc=['max', 'min','mean'])
pivot2.head()
# Out:
#                                     max             min            mean
#                         salary_year_avg salary_year_avg salary_year_avg
# company_name
# #twiceasnice Recruiting   120000.000000    61000.000000    77750.000000
# /dev/color                125000.000000   125000.000000   125000.000000
# 0nward Select              92500.000000    92500.000000    92500.000000
# 1 Point System            137290.484375   137290.484375   137290.484375
# 1 Point System LLC.       170000.000000   170000.000000   170000.000000

# %% [markdown]
# Problem Statement:
# Create a pivot table to calculate the median of salary_year_avg for each company_name and job_country:
#
# Filter the pivot table to only include 'Data Scientist' roles.
# Then filter the pivot table to only include company_name with a median salary_year_avg greater than 200,000.
# Display the first 10 rows of the resulting pivot table.
# Hint:
# Filter the DataFrame to only include Data Scientist roles. Use the pivot_table() function using the parameters values, index, and aggfunc. Then filter the pivot table using a condition.

# %%
df_DS = df[df['job_title'] == 'Data Scientist'].copy()
df_DS.head()
# Out:
#    job_title_short       job_title                           job_location  \
# 19  Data Scientist  Data Scientist               Pune, Maharashtra, India
# 20  Data Scientist  Data Scientist                      Zaventem, Belgium
# 29  Data Scientist  Data Scientist               Pune, Maharashtra, India
# 55  Data Scientist  Data Scientist  São Paulo, State of São Paulo, Brazil
# 62  Data Scientist  Data Scientist                             Austin, TX
#
#                job_via job_schedule_type  job_work_from_home search_location  \
# 19          via Indeed         Full-time               False           India
# 20  via BeBee Belgique         Full-time               False         Belgium
# 29          via Exusia         Full-time               False           India
# 55           via BeBee         Full-time               False          Brazil
# 62           via BeBee         Full-time               False           Sudan
#
# ...

# %%
pivot3 = df_DS.pivot_table(values='salary_year_avg', index=['company_name', 'job_country'], aggfunc='median')
filt_pivot3 = pivot3[pivot3['salary_year_avg'] > 200000]
filt_pivot3.head(10)
# Out:
#                                                            salary_year_avg
# company_name                                job_country
# Airtable                                    Sudan                 215500.0
# Algo Capital Group                          Sudan                 325000.0
#                                             United States         350000.0
# East River Electric Power Cooperative, Inc. United States         537000.0
# Federal Deposit Insurance Corporation       United States         210389.5
# Grammarly                                   United States         204500.0
# IBM                                         United States         213500.0
# INgrooves Music Group                       United States         250000.0
# INgroovesMusicGroup                         United States         250000.0
# Linquest Corporation                        Sudan                 375000.0
